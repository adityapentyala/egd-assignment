# %% [markdown]
# <a href="https://colab.research.google.com/github/Aarav-H/egd-assignment/blob/master/Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount = True)
# Out:
# Mounted at /content/drive

# %%
import sys
sys.path.append('/content/drive/MyDrive')

# %%
import pandas as pd
import math

# %%
df = pd.read_excel("/content/drive/MyDrive/worldbank_data_india_raw.xlsx")

# %%
df
# Out:
#   Country Name Country Code  \
# 0        India          IND
# 1        India          IND
# 2        India          IND
# 3        India          IND
# 4        India          IND
# 5        India          IND
# 6        India          IND
#
#                                          Series Name     Series Code  \
# 0                       GDP per capita (current US$)  NY.GDP.PCAP.CD
# 1               Gross domestic savings (current US$)  NY.GDS.TOTL.CD
# 2                                 Labor force, total  SL.TLF.TOTL.IN
# 3                 Military expenditure (current USD)  MS.MIL.XPND.CD
# 4  Net trade in goods and services (BoP, current ...  BN.GSR.GNFS.CD
# 5                  Consumer price index (2010 = 100)     FP.CPI.TOTL
# 6  Foreign direct investment, net (BoP, current US$)  BN.KLT.DINV.CD
#
#         1973 [YR1973]      1974 [YR1974]       1975 [YR1975]  \
# 0          143.456125         163.231616          157.929385
# ...

# %%
df.columns
# Out:
# Index(['Country Name', 'Country Code', 'Series Name', 'Series Code',
#        '1973 [YR1973]', '1974 [YR1974]', '1975 [YR1975]', '1976 [YR1976]',
#        '1977 [YR1977]', '1978 [YR1978]', '1979 [YR1979]', '1980 [YR1980]',
#        '1981 [YR1981]', '1982 [YR1982]', '1983 [YR1983]', '1984 [YR1984]',
#        '1985 [YR1985]', '1986 [YR1986]', '1987 [YR1987]', '1988 [YR1988]',
#        '1989 [YR1989]', '1990 [YR1990]', '1991 [YR1991]', '1992 [YR1992]',
#        '1993 [YR1993]', '1994 [YR1994]', '1995 [YR1995]', '1996 [YR1996]',
#        '1997 [YR1997]', '1998 [YR1998]', '1999 [YR1999]', '2000 [YR2000]',
#        '2001 [YR2001]', '2002 [YR2002]', '2003 [YR2003]', '2004 [YR2004]',
#        '2005 [YR2005]', '2006 [YR2006]', '2007 [YR2007]', '2008 [YR2008]',
#        '2009 [YR2009]', '2010 [YR2010]', '2011 [YR2011]', '2012 [YR2012]',
#        '2013 [YR2013]', '2014 [YR2014]', '2015 [YR2015]', '2016 [YR2016]',
#        '2017 [YR2017]', '2018 [YR2018]', '2019 [YR2019]', '2020 [YR2020]',
# ...

# %%
columns_delete=["Country Name", "Country Code", "Series Code",
       "1973 [YR1973]", "1974 [YR1974]", "1975 [YR1975]", "1976 [YR1976]",
       "1977 [YR1977]", "1978 [YR1978]", "1979 [YR1979]", "1980 [YR1980]",
       "1981 [YR1981]", "1982 [YR1982]", "1983 [YR1983]", "1984 [YR1984]",
       "1985 [YR1985]", "1986 [YR1986]", "1987 [YR1987]", "1988 [YR1988]",
       "1989 [YR1989]"]

# %%
df=df.drop(columns=columns_delete)
df
# Out:
#                                          Series Name       1990 [YR1990]  \
# 0                       GDP per capita (current US$)          368.749759
# 1               Gross domestic savings (current US$)  69457853636.794159
# 2                                 Labor force, total           292728665
# 3                 Military expenditure (current USD)  10537035450.052799
# 4  Net trade in goods and services (BoP, current ...     -6615557120.095
# 5                  Consumer price index (2010 = 100)           22.949008
# 6  Foreign direct investment, net (BoP, current US$)                  ..
#
#    1991 [YR1991]  1992 [YR1992]  1993 [YR1993]  1994 [YR1994]  1995 [YR1995]  \
# 0   3.038504e+02   3.175587e+02   3.015008e+02   3.462274e+02   3.736282e+02
# 1   5.916171e+10   6.726954e+10   6.576233e+10   8.091348e+10   9.280600e+10
# 2   2.997470e+08   3.069364e+08   3.143329e+08   3.220252e+08   3.331113e+08
# ...

# %%
df=df.transpose()
df
# Out:
#                                           0  \
# Series Name    GDP per capita (current US$)
# 1990 [YR1990]                    368.749759
# 1991 [YR1991]                    303.850438
# 1992 [YR1992]                    317.558739
# 1993 [YR1993]                    301.500791
# 1994 [YR1994]                    346.227393
# 1995 [YR1995]                    373.628236
# 1996 [YR1996]                    399.577312
# 1997 [YR1997]                     414.89868
# 1998 [YR1998]                    412.509354
# 1999 [YR1999]                    440.961455
# 2000 [YR2000]                    442.034779
# 2001 [YR2001]                    449.911125
# 2002 [YR2002]                    468.844428
# 2003 [YR2003]                    543.843799
# 2004 [YR2004]                    624.105094
# 2005 [YR2005]                    710.509345
# 2006 [YR2006]                    802.013742
# 2007 [YR2007]                   1022.732467
# 2008 [YR2008]                    993.503405
# ...

# %%
df.columns
df.head()
type(df[0])
# Out:
# pandas.core.series.Series

# %%
import numpy as np
label = "GDP per capita (current US$)"
df[0][0] = 1

# %%
#df[0] = df[0].apply(lambda x: math.log(x))
df[0] = np.log(np.array(df[0], dtype=np.float64))
# Out:
# <ipython-input-143-7dd462f0b51a>:2: RuntimeWarning: divide by zero encountered in log
#   df[0] = np.log(np.array(df[0], dtype=np.float64))

# %%
df[0][0] = label
df.head()
# Out:
# <ipython-input-144-a9769b9509c7>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[0][0] = label
#                                           0  \
# Series Name    GDP per capita (current US$)
# 1990 [YR1990]                          -inf
# 1991 [YR1991]                          -inf
# 1992 [YR1992]                          -inf
# 1993 [YR1993]                          -inf
#
#                                                   1                   2  \
# Series Name    Gross domestic savings (current US$)  Labor force, total
# 1990 [YR1990]                    69457853636.794159           292728665
# 1991 [YR1991]                    59161712842.495087         299747014.0
# 1992 [YR1992]                    67269535683.791504         306936389.0
# ...
